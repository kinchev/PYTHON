# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data=yf.download("KO",start="2019-01-01",end="2021-03-31",auto_adjust=True)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
start='2022-01-01'
end='2022-06-01'

# %%
btc=pd.read_csv("BTC-USD.csv",index_col=0)
eth=pd.read_csv("ETH-USD.csv",index_col=0)

# %%
btc=btc.loc["2022-01-02":"2022-06-01"]
eth=eth.loc["2022-01-02":"2022-06-01"]

# %%
# plt.style.use('seaborn-darkgrid')

# btc['Close'].plot(figsize=(40,8),color='green')
# plt.title('Closed Price BTC',fontsize=70)
# plt.xlabel('Year',fontsize=30)
# plt.ylabel('Price $',fontsize=30)

# plt.show()

# %%
plt.figure(figsize=(40,8))
plt.scatter(btc['Close'],eth['Close'])

plt.title('BTC Price Vs. ETH Price',fontsize=14)
plt.xlabel('BTC Price',fontsize=14)
plt.ylabel('ETH Price',fontsize=14)
plt.show()
